# %%
import pandas as pd

# load parquet files as pandas dataframe
aoi = pd.read_parquet('../../output/aoi_stats.parquet')
event = pd.read_parquet('../../output/event_stats.parquet')

df = pd.concat([aoi, event], axis=1)
duplicate_columns = df.columns[df.columns.duplicated()].unique().values
duplicate_columns
# Out:
# array(['Trial', 'Stimulus', 'Export End Trial Time [ms]', 'Participant',
#        'Color'], dtype=object)

# %%
df = df.loc[:, ~df.columns.duplicated()]
# df.to_csv('../../output/train_df.csv')
df
# Out:
#          Trial       Stimulus Export End Trial Time [ms]  Participant  \
# 0     Trial001  15_pasn_f.jpg                    10003.9            0
# 1     Trial002  19_naps_f.jpg                     9991.4            0
# 2     Trial003   1_aspn_f.jpg                     9990.7            0
# 3     Trial004   7_span_f.jpg                     9991.2            0
# 4     Trial005   5_ansp_f.jpg                     9991.3            0
# ...        ...            ...                        ...          ...
# 1507  Trial008  17_psna_f.jpg                    10007.1          124
# 1508  Trial009  15_pasn_f.jpg                     9991.4          124
# 1509  Trial010  21_nsap_f.jpg                     9988.5          124
# 1510  Trial011   9_sapn_f.jpg                     9991.6          124
# 1511  Trial012  23_ansp_f.jpg                     9992.2          124
#
#            Color    Class AOI Order sad AOI Size [px] sad  \
# 0      SlateGray  control             1            119584
# 1      SlateGray  control             2            119584
# 2      SlateGray  control             3            119584
# 3      SlateGray  control             4            119584
# 4      SlateGray  control             1            119584
# ...          ...      ...           ...               ...
# 1507  DodgerBlue  control             3            119584
# 1508  DodgerBlue  control             1            119584
# 1509  DodgerBlue  control             3            119584
# 1510  DodgerBlue  control             4            119584
# 1511  DodgerBlue  control             1            119584
#
#      AOI Coverage [%] sad Visible Time [ms] sad  ...  \
# 0                     6.8               10003.9  ...
# 1                     6.8                9991.4  ...
# 2                     6.8                9990.7  ...
# 3                     6.8                9991.2  ...
# 4                     6.8                9991.3  ...
# ...                   ...                   ...  ...
# 1507                  6.8               10007.1  ...
# 1508                  6.8                9991.4  ...
# 1509                  6.8                9988.5  ...
# 1510                  6.8                9991.6  ...
# 1511                  6.8                9992.2  ...
#
#      Saccade Velocity Maximum [°/s] Saccade Velocity Minimum [°/s]  \
# 0                             345.4                            7.4
# 1                             263.3                            3.0
# 2                             297.4                            7.6
# 3                             271.7                            6.4
# 4                             245.7                            4.5
# ...                             ...                            ...
# 1507                          339.4                            3.5
# 1508                          396.5                            3.2
# 1509                          303.5                            4.4
# 1510                          494.7                            6.2
# 1511                          321.4                            3.2
#
#      Saccade Latency Average [ms] Blink Count Blink Frequency [count/s]  \
# 0                           334.3           0                       0.0
# 1                           363.1           0                       0.0
# 2                           311.7           1                       0.1
# 3                           351.0           0                       0.0
# 4                           351.0           0                       0.0
# ...                           ...         ...                       ...
# 1507                        607.3           0                       0.0
# 1508                        352.3           1                       0.1
# 1509                        528.5           0                       0.0
# 1510                        427.4           1                       0.1
# 1511                        439.5           0                       0.0
#
#      Blink Duration Total [ms] Blink Duration Average [ms]  \
# 0                          0.0                           0
# 1                          0.0                           0
# 2                        125.1                       125.1
# 3                          0.0                           0
# 4                          0.0                           0
# ...                        ...                         ...
# 1507                       0.0                           0
# 1508                      83.5                        83.5
# 1509                       0.0                           0
# 1510                     100.0                       100.0
# 1511                       0.0                           0
#
#      Blink Duration Maximum [ms] Blink Duration Minimum [ms]  \
# 0                              0                           0
# 1                              0                           0
# 2                          125.1                       125.1
# 3                              0                           0
# 4                              0                           0
# ...                          ...                         ...
# 1507                           0                           0
# 1508                        83.5                        83.5
# 1509                           0                           0
# 1510                       100.0                       100.0
# 1511                           0                           0
#
#      Scanpath Length [px]
# 0                    8407
# 1                    6146
# 2                    7034
# 3                    6283
# 4                    5360
# ...                   ...
# 1507                 5403
# 1508                 9090
# 1509                 8166
# 1510                 6493
# 1511                 7783
#
# [1512 rows x 138 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test = train_test_split(df, test_size=0.2, stratify=df['Class'])
X_test.to_parquet('../../output/X_test.parquet')
X_train
# Out:
#          Trial       Stimulus Export End Trial Time [ms]  Participant  \
# 300   Trial001   9_sapn_f.jpg                     9991.2           25
# 669   Trial010  13_psan_f.jpg                     9996.2           54
# 576   Trial001  13_psan_f.jpg                     9994.1           47
# 316   Trial005   1_aspn_f.jpg                     9994.9           26
# 1113  Trial010  21_nsap_f.jpg                     9995.5           91
# ...        ...            ...                        ...          ...
# 88    Trial005   5_ansp_f.jpg                     9991.3            7
# 903   Trial004   5_ansp_f.jpg                     9993.5           74
# 361   Trial002  11_spna_f.jpg                    10000.2           30
# 395   Trial012   5_ansp_f.jpg                    10001.9           32
# 392   Trial009   1_aspn_f.jpg                    10002.0           32
#
#                Color       Class AOI Order sad AOI Size [px] sad  \
# 300       LightGreen     control             4            119584
# 669       DarkOrange  depressive             2            119584
# 576         DarkCyan  depressive             2            119584
# 316   CornflowerBlue  depressive             3            119584
# 1113       LightPink  depressive             2            119584
# ...              ...         ...           ...               ...
# 88    CornflowerBlue     control             1            119584
# 903        Firebrick  depressive             1            119584
# 361         DarkCyan  depressive             4            119584
# 395        DarkKhaki  depressive             1            119584
# 392        DarkKhaki  depressive             3            119584
#
#      AOI Coverage [%] sad Visible Time [ms] sad  ...  \
# 300                   6.8                9991.2  ...
# 669                   6.8                9996.2  ...
# 576                   6.8                9994.1  ...
# 316                   6.8                9994.9  ...
# 1113                  6.8                9995.5  ...
# ...                   ...                   ...  ...
# 88                    6.8                9991.3  ...
# 903                   6.8                9993.5  ...
# 361                   6.8               10000.2  ...
# 395                   6.8               10001.9  ...
# 392                   6.8               10002.0  ...
#
#      Saccade Velocity Maximum [°/s] Saccade Velocity Minimum [°/s]  \
# 300                           757.6                            4.8
# 669                           591.0                            3.1
# 576                           655.8                            8.4
# 316                           338.8                            3.4
# 1113                          217.2                            3.0
# ...                             ...                            ...
# 88                            995.0                            7.8
# 903                           261.8                           15.1
# 361                           379.5                            7.1
# 395                           519.2                            5.5
# 392                           283.5                            8.6
#
#      Saccade Latency Average [ms] Blink Count Blink Frequency [count/s]  \
# 300                         263.5           2                       0.2
# 669                         412.5           2                       0.2
# 576                         265.1           1                       0.1
# 316                         274.5           1                       0.1
# 1113                        480.8           0                       0.0
# ...                           ...         ...                       ...
# 88                          188.0           4                       0.4
# 903                         350.3           0                       0.0
# 361                         224.7           0                       0.0
# 395                         206.3           1                       0.1
# 392                         242.2           0                       0.0
#
#      Blink Duration Total [ms] Blink Duration Average [ms]  \
# 300                      258.6                       129.3
# 669                      267.0                       133.5
# 576                       75.1                        75.1
# 316                      150.1                       150.1
# 1113                       0.0                           0
# ...                        ...                         ...
# 88                       450.5                       112.6
# 903                        0.0                           0
# 361                        0.0                           0
# 395                       91.8                        91.8
# 392                        0.0                           0
#
#      Blink Duration Maximum [ms] Blink Duration Minimum [ms]  \
# 300                        158.5                       100.1
# 669                        158.5                       108.5
# 576                         75.1                        75.1
# 316                        150.1                       150.1
# 1113                           0                           0
# ...                          ...                         ...
# 88                         141.7                        83.5
# 903                            0                           0
# 361                            0                           0
# 395                         91.8                        91.8
# 392                            0                           0
#
#      Scanpath Length [px]
# 300                  9077
# 669                  4605
# 576                  5224
# 316                  6811
# 1113                 5603
# ...                   ...
# 88                   5864
# 903                  6714
# 361                  8190
# 395                  9105
# 392                  6251
#
# [1209 rows x 138 columns]

# %%
X_test.loc[X_test['Class'] == 'control']
# Out:
#          Trial       Stimulus Export End Trial Time [ms]  Participant  \
# 1495  Trial008  17_psna_f.jpg                     9991.1          123
# 44    Trial009  21_nsap_f.jpg                     9991.3            3
# 122   Trial003   7_span_f.jpg                     9991.0           10
# 1485  Trial010   9_sapn_f.jpg                     9991.1          122
# 129   Trial010   1_aspn_f.jpg                     9991.1           10
# ...        ...            ...                        ...          ...
# 131   Trial012  13_psan_f.jpg                     9991.5           10
# 1486  Trial011   5_ansp_f.jpg                     9992.1          122
# 1507  Trial008  17_psna_f.jpg                    10007.1          124
# 39    Trial004  13_psan_f.jpg                     9991.1            3
# 1290  Trial007   1_aspn_f.jpg                     9991.0          106
#
#               Color    Class AOI Order sad AOI Size [px] sad  \
# 1495          Khaki  control             3            119584
# 44             Gray  control             3            119584
# 122   PaleVioletRed  control             4            119584
# 1485        HotPink  control             4            119584
# 129   PaleVioletRed  control             3            119584
# ...             ...      ...           ...               ...
# 131   PaleVioletRed  control             3            119584
# 1486        HotPink  control             1            119584
# 1507     DodgerBlue  control             3            119584
# 39             Gray  control             3            119584
# 1290        DimGray  control             3            119584
#
#      AOI Coverage [%] sad Visible Time [ms] sad  ...  \
# 1495                  6.8                9991.1  ...
# 44                    6.8                9991.3  ...
# 122                   6.8                9991.0  ...
# 1485                  6.8                9991.1  ...
# 129                   6.8                9991.1  ...
# ...                   ...                   ...  ...
# 131                   6.8                9991.5  ...
# 1486                  6.8                9992.1  ...
# 1507                  6.8               10007.1  ...
# 39                    6.8                9991.1  ...
# 1290                  6.8                9991.0  ...
#
#      Saccade Velocity Maximum [°/s] Saccade Velocity Minimum [°/s]  \
# 1495                          253.9                            4.5
# 44                            641.0                            2.2
# 122                           288.9                            3.7
# 1485                          292.2                            3.5
# 129                           302.4                            5.0
# ...                             ...                            ...
# 131                           267.3                            3.5
# 1486                          550.5                            3.6
# 1507                          339.4                            3.5
# 39                            537.1                            3.4
# 1290                          578.2                            4.1
#
#      Saccade Latency Average [ms] Blink Count Blink Frequency [count/s]  \
# 1495                        363.7           0                       0.0
# 44                          300.0           0                       0.0
# 122                         589.5           0                       0.0
# 1485                        373.3           2                       0.2
# 129                         413.8           1                       0.1
# ...                           ...         ...                       ...
# 131                         424.5           0                       0.0
# 1486                        347.6           5                       0.5
# 1507                        607.3           0                       0.0
# 39                          304.0           1                       0.1
# 1290                        313.3           1                       0.1
#
#      Blink Duration Total [ms] Blink Duration Average [ms]  \
# 1495                       0.0                           0
# 44                         0.0                           0
# 122                        0.0                           0
# 1485                     166.9                        83.4
# 129                      166.9                       166.9
# ...                        ...                         ...
# 131                        0.0                           0
# 1486                     609.0                       121.8
# 1507                       0.0                           0
# 39                       116.7                       116.7
# 1290                     166.8                       166.8
#
#      Blink Duration Maximum [ms] Blink Duration Minimum [ms]  \
# 1495                           0                           0
# 44                             0                           0
# 122                            0                           0
# 1485                        91.7                        75.1
# 129                        166.9                       166.9
# ...                          ...                         ...
# 131                            0                           0
# 1486                       141.7                       100.1
# 1507                           0                           0
# 39                         116.7                       116.7
# 1290                       166.8                       166.8
#
#      Scanpath Length [px]
# 1495                 5332
# 44                   6922
# 122                  3641
# 1485                 7215
# 129                  5513
# ...                   ...
# 131                  3582
# 1486                 5528
# 1507                 5403
# 39                   6207
# 1290                 9029
#
# [108 rows x 138 columns]

# %%
from pycaret.classification import *

s = setup(X_train, target = 'Class', session_id = 123)
# Out:
# <style type="text/css">
# #T_2066c_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2066c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2066c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2066c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2066c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2066c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2066c_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_2066c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2066c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2066c_row1_col1" class="data row1 col1" >Class</td>
#     </tr>
#     <tr>
#       <th id="T_2066c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2066c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_2066c_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_2066c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2066c_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_2066c_row3_col1" class="data row3 col1" >control: 0, depressive: 1</td>
#     </tr>
#     <tr>
#       <th id="T_2066c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2066c_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_2066c_row4_col1" class="data row4 col1" >(1209, 138)</td>
#     </tr>
#     <tr>
#       <th id="T_2066c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2066c_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_2066c_row5_col1" class="data row5 col1" >(1209, 411)</td>
#     </tr>
#     <tr>
#       <th id="T_2066c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2066c_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_2066c_row6_col1" class="data row6 col1" >(846, 411)</td>
#     </tr>
#     <tr>
#       <th id="T_2066c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2066c_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_2066c_row7_col1" class="data row7 col1" >(363, 411)</td>
#     </tr>
#     <tr>
#       <th id="T_2066c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2066c_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_2066c_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_2066c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2066c_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_2066c_row9_col1" class="data row9 col1" >136</td>
#     </tr>
#     <tr>
#       <th id="T_2066c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2066c_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_2066c_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2066c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2066c_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_2066c_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_2066c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2066c_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_2066c_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_2066c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2066c_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_2066c_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_2066c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2066c_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_2066c_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_2066c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2066c_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_2066c_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_2066c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2066c_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_2066c_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_2066c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_2066c_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_2066c_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_2066c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_2066c_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_2066c_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_2066c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_2066c_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_2066c_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2066c_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_2066c_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_2066c_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2066c_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_2066c_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_2066c_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_2066c_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_2066c_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_2066c_row22_col1" class="data row22 col1" >038b</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_d2750 th {
#   text-align: left;
# }
# #T_d2750_row0_col0, #T_d2750_row1_col0, #T_d2750_row1_col1, #T_d2750_row1_col3, #T_d2750_row1_col4, #T_d2750_row1_col5, #T_d2750_row1_col6, #T_d2750_row1_col7, #T_d2750_row2_col0, #T_d2750_row2_col1, #T_d2750_row2_col3, #T_d2750_row2_col4, #T_d2750_row2_col5, #T_d2750_row2_col6, #T_d2750_row2_col7, #T_d2750_row3_col0, #T_d2750_row3_col1, #T_d2750_row3_col3, #T_d2750_row3_col4, #T_d2750_row3_col5, #T_d2750_row3_col6, #T_d2750_row3_col7, #T_d2750_row4_col0, #T_d2750_row4_col1, #T_d2750_row4_col3, #T_d2750_row4_col4, #T_d2750_row4_col5, #T_d2750_row4_col6, #T_d2750_row4_col7, #T_d2750_row5_col0, #T_d2750_row5_col1, #T_d2750_row5_col3, #T_d2750_row5_col4, #T_d2750_row5_col5, #T_d2750_row5_col6, #T_d2750_row5_col7, #T_d2750_row6_col0, #T_d2750_row6_col1, #T_d2750_row6_col3, #T_d2750_row6_col4, #T_d2750_row6_col5, #T_d2750_row6_col6, #T_d2750_row6_col7, #T_d2750_row7_col0, #T_d2750_row7_col1, #T_d2750_row7_col3, #T_d2750_row7_col4, #T_d2750_row7_col5, #T_d2750_row7_col6, #T_d2750_row7_col7, #T_d2750_row8_col0, #T_d2750_row8_col1, #T_d2750_row8_col3, #T_d2750_row8_col4, #T_d2750_row8_col5, #T_d2750_row8_col6, #T_d2750_row8_col7, #T_d2750_row9_col0, #T_d2750_row9_col1, #T_d2750_row9_col3, #T_d2750_row9_col4, #T_d2750_row9_col5, #T_d2750_row9_col6, #T_d2750_row9_col7, #T_d2750_row10_col0, #T_d2750_row10_col1, #T_d2750_row10_col3, #T_d2750_row10_col4, #T_d2750_row10_col5, #T_d2750_row10_col6, #T_d2750_row10_col7, #T_d2750_row11_col0, #T_d2750_row11_col1, #T_d2750_row11_col3, #T_d2750_row11_col4, #T_d2750_row11_col5, #T_d2750_row11_col6, #T_d2750_row11_col7, #T_d2750_row12_col0, #T_d2750_row12_col1, #T_d2750_row12_col3, #T_d2750_row12_col4, #T_d2750_row12_col5, #T_d2750_row12_col6, #T_d2750_row12_col7, #T_d2750_row13_col0, #T_d2750_row13_col1, #T_d2750_row13_col3, #T_d2750_row13_col4, #T_d2750_row13_col5, #T_d2750_row13_col6, #T_d2750_row13_col7 {
#   text-align: left;
# }
# #T_d2750_row0_col1, #T_d2750_row0_col2, #T_d2750_row0_col3, #T_d2750_row0_col4, #T_d2750_row0_col5, #T_d2750_row0_col6, #T_d2750_row0_col7, #T_d2750_row1_col2, #T_d2750_row2_col2, #T_d2750_row3_col2, #T_d2750_row4_col2, #T_d2750_row5_col2, #T_d2750_row6_col2, #T_d2750_row7_col2, #T_d2750_row8_col2, #T_d2750_row9_col2, #T_d2750_row10_col2, #T_d2750_row11_col2, #T_d2750_row12_col2, #T_d2750_row13_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d2750_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_d2750_row1_col8, #T_d2750_row2_col8, #T_d2750_row3_col8, #T_d2750_row4_col8, #T_d2750_row5_col8, #T_d2750_row6_col8, #T_d2750_row7_col8, #T_d2750_row8_col8, #T_d2750_row9_col8, #T_d2750_row10_col8, #T_d2750_row11_col8, #T_d2750_row12_col8, #T_d2750_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d2750">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2750_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d2750_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_d2750_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_d2750_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_d2750_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_d2750_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_d2750_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_d2750_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_d2750_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2750_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_d2750_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_d2750_row0_col1" class="data row0 col1" >0.9976</td>
#       <td id="T_d2750_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_d2750_row0_col3" class="data row0 col3" >0.9976</td>
#       <td id="T_d2750_row0_col4" class="data row0 col4" >0.9977</td>
#       <td id="T_d2750_row0_col5" class="data row0 col5" >0.9976</td>
#       <td id="T_d2750_row0_col6" class="data row0 col6" >0.9948</td>
#       <td id="T_d2750_row0_col7" class="data row0 col7" >0.9949</td>
#       <td id="T_d2750_row0_col8" class="data row0 col8" >2.8980</td>
#     </tr>
#     <tr>
#       <th id="T_d2750_level0_row1" class="row_heading level0 row1" >qda</th>
#       <td id="T_d2750_row1_col0" class="data row1 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_d2750_row1_col1" class="data row1 col1" >0.9882</td>
#       <td id="T_d2750_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_d2750_row1_col3" class="data row1 col3" >0.9882</td>
#       <td id="T_d2750_row1_col4" class="data row1 col4" >0.9888</td>
#       <td id="T_d2750_row1_col5" class="data row1 col5" >0.9883</td>
#       <td id="T_d2750_row1_col6" class="data row1 col6" >0.9746</td>
#       <td id="T_d2750_row1_col7" class="data row1 col7" >0.9751</td>
#       <td id="T_d2750_row1_col8" class="data row1 col8" >3.4350</td>
#     </tr>
#     <tr>
#       <th id="T_d2750_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_d2750_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_d2750_row2_col1" class="data row2 col1" >0.8794</td>
#       <td id="T_d2750_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_d2750_row2_col3" class="data row2 col3" >0.8794</td>
#       <td id="T_d2750_row2_col4" class="data row2 col4" >0.8963</td>
#       <td id="T_d2750_row2_col5" class="data row2 col5" >0.8723</td>
#       <td id="T_d2750_row2_col6" class="data row2 col6" >0.7165</td>
#       <td id="T_d2750_row2_col7" class="data row2 col7" >0.7446</td>
#       <td id="T_d2750_row2_col8" class="data row2 col8" >4.0860</td>
#     </tr>
#     <tr>
#       <th id="T_d2750_level0_row3" class="row_heading level0 row3" >nb</th>
#       <td id="T_d2750_row3_col0" class="data row3 col0" >Naive Bayes</td>
#       <td id="T_d2750_row3_col1" class="data row3 col1" >0.7884</td>
#       <td id="T_d2750_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_d2750_row3_col3" class="data row3 col3" >0.7884</td>
#       <td id="T_d2750_row3_col4" class="data row3 col4" >0.8218</td>
#       <td id="T_d2750_row3_col5" class="data row3 col5" >0.7632</td>
#       <td id="T_d2750_row3_col6" class="data row3 col6" >0.4766</td>
#       <td id="T_d2750_row3_col7" class="data row3 col7" >0.5393</td>
#       <td id="T_d2750_row3_col8" class="data row3 col8" >3.2960</td>
#     </tr>
#     <tr>
#       <th id="T_d2750_level0_row4" class="row_heading level0 row4" >svm</th>
#       <td id="T_d2750_row4_col0" class="data row4 col0" >SVM - Linear Kernel</td>
#       <td id="T_d2750_row4_col1" class="data row4 col1" >0.6772</td>
#       <td id="T_d2750_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_d2750_row4_col3" class="data row4 col3" >0.6772</td>
#       <td id="T_d2750_row4_col4" class="data row4 col4" >0.7451</td>
#       <td id="T_d2750_row4_col5" class="data row4 col5" >0.6466</td>
#       <td id="T_d2750_row4_col6" class="data row4 col6" >0.3582</td>
#       <td id="T_d2750_row4_col7" class="data row4 col7" >0.3946</td>
#       <td id="T_d2750_row4_col8" class="data row4 col8" >3.6440</td>
#     </tr>
#     <tr>
#       <th id="T_d2750_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_d2750_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_d2750_row5_col1" class="data row5 col1" >0.6668</td>
#       <td id="T_d2750_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_d2750_row5_col3" class="data row5 col3" >0.6668</td>
#       <td id="T_d2750_row5_col4" class="data row5 col4" >0.5863</td>
#       <td id="T_d2750_row5_col5" class="data row5 col5" >0.5797</td>
#       <td id="T_d2750_row5_col6" class="data row5 col6" >0.1156</td>
#       <td id="T_d2750_row5_col7" class="data row5 col7" >0.1288</td>
#       <td id="T_

# %%
save_model(best, '../../model/model_oczy')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None, include=['Participant'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy...
#                                                                min_samples_leaf=20,
#                                                                return_df=True,
#                                                                smoothing=10,
#                                                                verbose=0))),
#                  ('clean_column_names',
#                   TransformerWrapper(exclude=None, include=None,
#                                      transformer=CleanColumnNames(match='[\\]\\[\\,\\{\\}\\"\\:]+'))),
#                  ('trained_model',
#                   KNeighborsClassifier(algorithm='auto', leaf_size=30,
#                                        metric='minkowski', metric_params=None,
#                                        n_jobs=-1, n_neighbors=5, p=2,
#                                        weights='uniform'))],
#           verbose=False),
#  '../../model/model_oczy_new.pkl')
