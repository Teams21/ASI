# %%
from pycaret.classification import *
import pandas as pd
model = load_model('../../model/model_oczy')
X_test = pd.read_parquet('../../output/X_test.parquet')
y_test = X_test['Class']
X_test = X_test.drop('Class', axis=1)
prediction = predict_model(model, data = X_test)
prediction = pd.concat([prediction, y_test], axis=1)
prediction
# Out:
# Transformation Pipeline and Model Successfully Loaded
#          Trial       Stimulus Export End Trial Time [ms]  Participant  \
# 1495  Trial008  17_psna_f.jpg                     9991.1          123
# 736   Trial005   7_span_f.jpg                     9994.3           60
# 443   Trial012  23_ansp_f.jpg                     9999.4           36
# 44    Trial009  21_nsap_f.jpg                     9991.3            3
# 910   Trial011  19_naps_f.jpg                     9992.3           74
# ...        ...            ...                        ...          ...
# 1290  Trial007   1_aspn_f.jpg                     9991.0          106
# 419   Trial012  11_spna_f.jpg                     9994.7           34
# 1019  Trial012  13_psan_f.jpg                     9999.6           83
# 580   Trial005  23_ansp_f.jpg                    10000.7           47
# 852   Trial001  11_spna_f.jpg                    10000.3           70
#
#               Color AOI Order sad AOI Size [px] sad AOI Coverage [%] sad  \
# 1495          Khaki             3            119584                  6.8
# 736   DarkSlateGray             3            119584                  6.8
# 443      DarkOrchid             1            119584                  6.8
# 44             Gray             3            119584                  6.8
# 910       Firebrick             4            119584                  6.8
# ...             ...           ...               ...                  ...
# 1290        DimGray             3            119584                  6.8
# 419   DarkSlateBlue             4            119584                  6.8
# 1019      IndianRed             2            119584                  6.8
# 580        DarkCyan             1            119584                  6.8
# 852         DarkRed             4            119584                  6.8
#
#      Visible Time [ms] sad Entry Time [ms] sad  ... Blink Count  \
# 1495                9991.1              4451.4  ...           0
# 736                 9994.3               267.7  ...           2
# 443                 9999.4              4226.8  ...           0
# 44                  9991.3              1053.0  ...           0
# 910                 9992.3              3268.8  ...           1
# ...                    ...                 ...  ...         ...
# 1290                9991.0               952.3  ...           1
# 419                 9994.7               359.9  ...           2
# 1019                9999.6              9590.7  ...           2
# 580                10000.7              4386.7  ...           0
# 852                10000.3              2659.5  ...           5
#
#      Blink Frequency [count/s] Blink Duration Total [ms]  \
# 1495                       0.0                       0.0
# 736                        0.2                     233.5
# 443                        0.0                       0.0
# 44                         0.0                       0.0
# 910                        0.1                     125.1
# ...                        ...                       ...
# 1290                       0.1                     166.8
# 419                        0.2                     175.2
# 1019                       0.2                     417.1
# 580                        0.0                       0.0
# 852                        0.5                     600.6
#
#      Blink Duration Average [ms] Blink Duration Maximum [ms]  \
# 1495                           0                           0
# 736                        116.8                       125.1
# 443                            0                           0
# 44                             0                           0
# 910                        125.1                       125.1
# ...                          ...                         ...
# 1290                       166.8                       166.8
# 419                         87.6                       100.1
# 1019                       208.5                       266.8
# 580                            0                           0
# 852                        120.1                       133.5
#
#      Blink Duration Minimum [ms] Scanpath Length [px] prediction_label  \
# 1495                           0                 5332          control
# 736                        108.4                 6553       depressive
# 443                            0                 6124       depressive
# 44                             0                 6922          control
# 910                        125.1                 7143       depressive
# ...                          ...                  ...              ...
# 1290                       166.8                 9029          control
# 419                         75.1                 8425       depressive
# 1019                       150.2                 3363       depressive
# 580                            0                 5375       depressive
# 852                        100.1                 7257       depressive
#
#      prediction_score       Class
# 1495              1.0     control
# 736               1.0  depressive
# 443               1.0  depressive
# 44                1.0     control
# 910               1.0  depressive
# ...               ...         ...
# 1290              1.0     control
# 419               1.0  depressive
# 1019              1.0  depressive
# 580               1.0  depressive
# 852               1.0  depressive
#
# [303 rows x 140 columns]

# %%
pd.set_option('display.max_rows', None)

display((prediction['Class'] == prediction['prediction_label']).sort_values())
# Out:
# 310     False
# 303     False
# 1495     True
# 962      True
# 1457     True
# 137      True
# 586      True
# 240      True
# 575      True
# 604      True
# 1406     True
# 338      True
# 486      True
# 1459     True
# 276      True
# 1510     True
# 107      True
# 1239     True
# 1253     True
# 713      True
# 327      True
# 1187     True
# 77       True
# 1228     True
# 644      True
# 1339     True
# 1154     True
# 437      True
# 1368     True
# 29       True
# 620      True
# 188      True
# 922      True
# 231      True
# 1476     True
# 650      True
# 24       True
# 1351     True
# 688      True
# 829      True
# 11       True
# 1311     True
# 572      True
# 1442     True
# 657      True
# 1292     True
# 445      True
# 1046     True
# 181      True
# 1173     True
# 1051     True
# 165      True
# 810      True
# 775      True
# 1163     True
# 1417     True
# 631      True
# 127      True
# 1110     True
# 155      True
# 1447     True
# 342      True
# 196      True
# 741      True
# 724      True
# 112      True
# 51       True
# 1177     True
# 648      True
# 607      True
# 84       True
# 878      True
# 540      True
# 1047     True
# 629      True
# 1400     True
# 921      True
# 1093     True
# 199      True
# 36       True
# 1256     True
# 481      True
# 412      True
# 742      True
# 128      True
# 26       True
# 796      True
# 1298     True
# 837      True
# 1077     True
# 334      True
# 1212     True
# 596      True
# 870      True
# 895      True
# 862      True
# 1019     True
# 419      True
# 1290     True
# 646      True
# 39       True
# 1507     True
# 832      True
# 1081     True
# 880      True
# 1486     True
# 1116     True
# 1034     True
# 346      True
# 131      True
# 769      True
# 1131     True
# 729      True
# 1258     True
# 16       True
# 875      True
# 867      True
# 343      True
# 674      True
# 615      True
# 907      True
# 1246     True
# 350      True
# 28       True
# 721      True
# 87       True
# 704      True
# 1451     True
# 585      True
# 882      True
# 186      True
# 389      True
# 1023     True
# 1205     True
# 1045     True
# 1427     True
# 854      True
# 1403     True
# 1102     True
# 95       True
# 472      True
# 115      True
# 1353     True
# 1347     True
# 764      True
# 1086     True
# 1236     True
# 116      True
# 502      True
# 442      True
# 846      True
# 230      True
# 533      True
# 678      True
# 476      True
# 377      True
# 1364     True
# 988      True
# 1084     True
# 594      True
# 325      True
# 498      True
# 1094     True
# 1054     True
# 14       True
# 19       True
# 394      True
# 319      True
# 1160     True
# 37       True
# 840      True
# 680      True
# 274      True
# 135      True
# 1423     True
# 132      True
# 1224     True
# 1097     True
# 374      True
# 573      True
# 1117     True
# 1463     True
# 807      True
# 528      True
# 745      True
# 1454     True
# 1411     True
# 979      True
# 1085     True
# 1316     True
# 534      True
# 749      True
# 142      True
# 531      True
# 416      True
# 1359     True
# 842      True
# 1312     True
# 22       True
# 129      True
# 1485     True
# 122      True
# 910      True
# 44       True
# 443      True
# 736      True
# 92       True
# 218      True
# 587      True
# 320      True
# 454      True
# 76       True
# 1286     True
# 866      True
# 492      True
# 1268     True
# 519      True
# 750      True
# 1260     True
# 1379     True
# 326      True
# 1328     True
# 1341     True
# 1404     True
# 561      True
# 83       True
# 580      True
# 1241     True
# 1169     True
# 871      True
# 1355     True
# 1064     True
# 627      True
# 341      True
# 2        True
# 431      True
# 825      True
# 537      True
# 944      True
# 857      True
# 447      True
# 337      True
# 972      True
# 402      True
# 841      True
# 980      True
# 642      True
# 687      True
# 100      True
# 975      True
# 1006     True
# 1044     True
# 1280     True
# 1276     True
# 1146     True
# 1444     True
# 1345     True
# 923      True
# 136      True
# 484      True
# 1069     True
# 611      True
# 211      True
# 723      True
# 1091     True
# 0        True
# 3        True
# 1216     True
# 1184     True
# 1039     True
# 480      True
# 699      True
# 393      True
# 153      True
# 125      True
# 10       True
# 968      True
# 358      True
# 1151     True
# 1314     True
# 844      True
# 1133     True
# 1288     True
# 1145     True
# 470      True
# 985      True
# 600      True
# 1294     True
# 753      True
# 13       True
# 47       True
# 134      True
# 469      True
# 1387     True
# 8        True
# 552      True
# 1480     True
# 490      True
# 1109     True
# 1018     True
# 525      True
# 788      True
# 852      True
# dtype: bool
